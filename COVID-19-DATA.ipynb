# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import and clean confirmed cases data

# %%
confirmed_raw = pd.read_csv("time_series_covid19_confirmed_global.csv")

# %%
confirmed_raw.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  \
# 0        0        0        0  ...     423     444     484      521      555
# 1        0        0        0  ...     383     400     409      416      433
# 2        0        0        0  ...    1468    1572    1666     1761     1825
# 3        0        0        0  ...     545     564     583      601      601
# 4        0        0        0  ...      17      19      19       19       19
#
#    4/12/20  4/13/20  4/14/20  4/15/20  4/16/20
# 0      607      665      714      784      840
# 1      446      467      475      494      518
# 2     1914     1983     2070     2160     2268
# 3      638      646      659      673      673
# 4       19       19       19       19       19
#
# [5 rows x 90 columns]

# %%
confirmed_raw.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
#        '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
#        '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
#        '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
#        '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
#        '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
#        '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
#        '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
#        '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20',
#        '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20', '4/1/20',
#        '4/2/20', '4/3/20', '4/4/20', '4/5/20', '4/6/20', '4/7/20', '4/8/20',
#        '4/9/20', '4/10/20', '4/11/20', '4/12/20', '4/13/20', '4/14/20',
#        '4/15/20', '4/16/20'],
#       dtype='object')

# %%
confirmed = pd.melt(confirmed_raw, id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'], var_name="Date", value_name="Confirmed")

# %%
confirmed.head()
# Out:
#   Province/State Country/Region      Lat     Long     Date  Confirmed
# 0            NaN    Afghanistan  33.0000  65.0000  1/22/20          0
# 1            NaN        Albania  41.1533  20.1683  1/22/20          0
# 2            NaN        Algeria  28.0339   1.6596  1/22/20          0
# 3            NaN        Andorra  42.5063   1.5218  1/22/20          0
# 4            NaN         Angola -11.2027  17.8739  1/22/20          0

# %%
pd.isna(confirmed["Province/State"]).sum()
# Out:
# 15652

# %%
confirmed["Province/State"] = confirmed["Province/State"].fillna("None")

# %%
pd.isna(confirmed["Province/State"]).sum()
# Out:
# 0

# %% [markdown]
# # Import and clean reported deaths data

# %%
deaths_raw = pd.read_csv("time_series_covid19_deaths_global.csv")

# %%
deaths_raw.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  \
# 0        0        0        0  ...      14      14      15       15       18
# 1        0        0        0  ...      22      22      23       23       23
# 2        0        0        0  ...     193     205     235      256      275
# 3        0        0        0  ...      22      23      25       26       26
# 4        0        0        0  ...       2       2       2        2        2
#
#    4/12/20  4/13/20  4/14/20  4/15/20  4/16/20
# 0       18       21       23       25       30
# 1       23       23       24       25       26
# 2      293      313      326      336      348
# 3       29       29       31       33       33
# 4        2        2        2        2        2
#
# [5 rows x 90 columns]

# %%
deaths = pd.melt(deaths_raw, id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'], var_name="Date", value_name="Deaths")

# %%
deaths.head()
# Out:
#   Province/State Country/Region      Lat     Long     Date  Deaths
# 0            NaN    Afghanistan  33.0000  65.0000  1/22/20       0
# 1            NaN        Albania  41.1533  20.1683  1/22/20       0
# 2            NaN        Algeria  28.0339   1.6596  1/22/20       0
# 3            NaN        Andorra  42.5063   1.5218  1/22/20       0
# 4            NaN         Angola -11.2027  17.8739  1/22/20       0

# %%
pd.isna(deaths["Province/State"]).sum()
# Out:
# 15652

# %%
deaths["Province/State"] = deaths["Province/State"].fillna("None")

# %%
pd.isna(deaths["Province/State"]).sum()
# Out:
# 0

# %%
deaths.head()
# Out:
#   Province/State Country/Region      Lat     Long     Date  Deaths
# 0           None    Afghanistan  33.0000  65.0000  1/22/20       0
# 1           None        Albania  41.1533  20.1683  1/22/20       0
# 2           None        Algeria  28.0339   1.6596  1/22/20       0
# 3           None        Andorra  42.5063   1.5218  1/22/20       0
# 4           None         Angola -11.2027  17.8739  1/22/20       0

# %% [markdown]
# # Import and clean recovered data

# %%
recovered_raw = pd.read_csv("time_series_covid19_recovered_global.csv")

# %%
recovered_raw.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  \
# 0        0        0        0  ...      18      29      32       32       32
# 1        0        0        0  ...     131     154     165      182      197
# 2        0        0        0  ...     113     237     347      405      460
# 3        0        0        0  ...      39      52      58       71       71
# 4        0        0        0  ...       2       2       2        2        4
#
#    4/12/20  4/13/20  4/14/20  4/15/20  4/16/20
# 0       32       32       40       43       54
# 1      217      232      248      251      277
# 2      591      601      691      708      783
# 3      128      128      128      169      169
# 4        4        4        5        5        5
#
# [5 rows x 90 columns]

# %%
recovered = pd.melt(recovered_raw, id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'], var_name="Date", value_name="Recovered")

# %%
recovered.head()
# Out:
#   Province/State Country/Region      Lat     Long     Date  Recovered
# 0            NaN    Afghanistan  33.0000  65.0000  1/22/20          0
# 1            NaN        Albania  41.1533  20.1683  1/22/20          0
# 2            NaN        Algeria  28.0339   1.6596  1/22/20          0
# 3            NaN        Andorra  42.5063   1.5218  1/22/20          0
# 4            NaN         Angola -11.2027  17.8739  1/22/20          0

# %%
pd.isna(recovered["Province/State"]).sum()
# Out:
# 15738

# %%
recovered["Province/State"] = recovered["Province/State"].fillna("None")

# %%
pd.isna(recovered["Province/State"]).sum()
# Out:
# 0

# %%
recovered.head()
# Out:
#   Province/State Country/Region      Lat     Long     Date  Recovered
# 0           None    Afghanistan  33.0000  65.0000  1/22/20          0
# 1           None        Albania  41.1533  20.1683  1/22/20          0
# 2           None        Algeria  28.0339   1.6596  1/22/20          0
# 3           None        Andorra  42.5063   1.5218  1/22/20          0
# 4           None         Angola -11.2027  17.8739  1/22/20          0

# %% [markdown]
# # Merge the data

# %%
confirmed.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed'], dtype='object')

# %%
merge_1 = pd.merge(confirmed, deaths, on=['Province/State', 'Country/Region','Date'])

# %%
merge_1.head()
# Out:
#   Province/State Country/Region    Lat_x   Long_x     Date  Confirmed  \
# 0           None    Afghanistan  33.0000  65.0000  1/22/20          0
# 1           None        Albania  41.1533  20.1683  1/22/20          0
# 2           None        Algeria  28.0339   1.6596  1/22/20          0
# 3           None        Andorra  42.5063   1.5218  1/22/20          0
# 4           None         Angola -11.2027  17.8739  1/22/20          0
#
#      Lat_y   Long_y  Deaths
# 0  33.0000  65.0000       0
# 1  41.1533  20.1683       0
# 2  28.0339   1.6596       0
# 3  42.5063   1.5218       0
# 4 -11.2027  17.8739       0

# %%
len(merge_1)
# Out:
# 22704

# %%
covid_19 = pd.merge(merge_1, recovered, on=['Province/State', 'Country/Region','Date'])

# %%
covid_19.head()
# Out:
#   Province/State Country/Region    Lat_x   Long_x     Date  Confirmed  \
# 0           None    Afghanistan  33.0000  65.0000  1/22/20          0
# 1           None        Albania  41.1533  20.1683  1/22/20          0
# 2           None        Algeria  28.0339   1.6596  1/22/20          0
# 3           None        Andorra  42.5063   1.5218  1/22/20          0
# 4           None         Angola -11.2027  17.8739  1/22/20          0
#
#      Lat_y   Long_y  Deaths      Lat     Long  Recovered
# 0  33.0000  65.0000       0  33.0000  65.0000          0
# 1  41.1533  20.1683       0  41.1533  20.1683          0
# 2  28.0339   1.6596       0  28.0339   1.6596          0
# 3  42.5063   1.5218       0  42.5063   1.5218          0
# 4 -11.2027  17.8739       0 -11.2027  17.8739          0

# %%
covid_19 = covid_19.drop(columns=['Lat_x', 'Long_x', 'Lat_y', 'Long_y'])

# %%
covid_19.head()
# Out:
#   Province/State Country/Region     Date  Confirmed  Deaths      Lat     Long  \
# 0           None    Afghanistan  1/22/20          0       0  33.0000  65.0000
# 1           None        Albania  1/22/20          0       0  41.1533  20.1683
# 2           None        Algeria  1/22/20          0       0  28.0339   1.6596
# 3           None        Andorra  1/22/20          0       0  42.5063   1.5218
# 4           None         Angola  1/22/20          0       0 -11.2027  17.8739
#
#    Recovered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# # Export to csv

# %%
covid_19.to_csv("covid_19_data.csv", index=False)
